# %% [markdown]
# # WDI api indicators

# %%
from langchain.llms import OpenAI
from langchain.chat_models import ChatOpenAI
import pandas as pd
import json
import os
import openai
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

openai.api_key  = os.getenv('OPENAI_API_KEY')

# %%
# Temp = 0 so that we get clean information without a lot of creativity
chat_model = ChatOpenAI(temperature=0, max_tokens=1000)

# %%
from langchain.document_loaders import DataFrameLoader
df = wb.series.info()  
loader = DataFrameLoader(df, page_content_column="id")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 3
#       1 from langchain.document_loaders import DataFrameLoader
#       2 df = wb.series.info()
# ----> 3 loader = DataFrameLoader(df, page_content_column="id")
#
# File /opt/homebrew/lib/python3.9/site-packages/langchain/document_loaders/dataframe.py:16, in DataFrameLoader.__init__(self, data_frame, page_content_column)
#      13 import pandas as pd
#      15 if not isinstance(data_frame, pd.DataFrame):
# ---> 16     raise ValueError(
#      17         f"Expected data_frame to be a pd.DataFrame, got {type(data_frame)}"
#      18     )
#      19 self.data_frame = data_frame
#      20 self.page_content_column = page_content_column
#
# ValueError: Expected data_frame to be a pd.DataFrame, got <class 'wbgapi.Featureset'>

# %%
import wbgapi as wb
wb.search('fossil fuels')
# Out:
# ========
# Series: EG.ELC.COAL.KH
#
# Developmentrelevance: ...from fossil fuel combustion and cement manufacturing. In combustion different fossil fuels release different amounts of carbon dioxide for the same level of energy use:...
# ========
# Series: EG.ELC.COAL.ZS
#
# Developmentrelevance: ...from fossil fuel combustion and cement manufacturing. In combustion different fossil fuels release different amounts of carbon dioxide for the same level of energy use:...
# ========
# Series: EG.ELC.HYRO.KH
#
# Developmentrelevance: ...from fossil fuel combustion and cement manufacturing. In combustion different fossil fuels release different amounts of carbon dioxide for the same level of energy use:...
# ========
# Series: EG.ELC.HYRO.ZS
#
# Developmentrelevance: ...from fossil fuel combustion and cement manufacturing. In combustion different fossil fuels release different amounts of carbon dioxide for the same level of energy use:...
# ========
# Series: EG.ELC.NGAS.KH
#
# Developmentrelevance: ...2) lower carbon relative to other fossil fuels;...
# ========
# Series: EG.ELC.NGAS.ZS
#
# Developmentrelevance: ...2) lower carbon relative to other fossil fuels;...
# ========
# Series: EG.ELC.NUCL.KH
#
# Developmentrelevance: ...grew rapidly in the 1970s and 1980s as countries sought to reduce dependence on fossil fuels, especially after the oil crises of the 1970s. There was a renewed interest in...
# ========
# Series: EG.ELC.NUCL.ZS
#
# Developmentrelevance: ...grew rapidly in the 1970s and 1980s as countries sought to reduce dependence on fossil fuels, especially after the oil crises of the 1970s. There was a renewed interest in...
# ========
# Series: EG.ELC.PETR.KH
#
# Developmentrelevance: ...from fossil fuel combustion and cement manufacturing. In combustion different fossil fuels release different amounts of carbon dioxide for the same level of energy use:...
# ========
# Series: EG.ELC.PETR.ZS
#
# Developmentrelevance: ...from fossil fuel combustion and cement manufacturing. In combustion different fossil fuels release different amounts of carbon dioxide for the same level of energy use:...
# ========
# Series: EG.ELC.PROD.KH
#
# Developmentrelevance: ...from fossil fuel combustion and cement manufacturing. In combustion different fossil fuels release different amounts of carbon dioxide for the same level of energy use:...
# ========
# Series: EG.GDP.PUSE.KO.PP.KD
#
# Developmentrelevance: ...Fossil fuels are non-renewable resources because they take millions of years to form, and...
# ========
# Series: EG.USE.COMM.CL.ZS
#
# Developmentrelevance: ...energy is produced without the undesirable consequences of the burning of fossil fuels, such as high carbon dioxide emissions, which is considered to be the major...
# ========
# Series: EG.USE.COMM.FO.ZS
#
# Developmentrelevance: ...Fossil fuels are non-renewable resources because they take millions of years to form, and...
# ========
# Series: EG.USE.COMM.KT.OE
#
# Developmentrelevance: ...Fossil fuels are non-renewable resources because they take millions of years to form, and...
# ========
# Series: EN.ATM.CO2E.EG.ZS
#
# Limitationsandexceptions: ...Data for carbon dioxide emissions include gases from the burning of fossil fuels and cement manufacture, but excludes emissions from land use such as...
# --------
# Statisticalconceptandmethodology: ...from fossil fuel combustion and cement manufacturing. In combustion different fossil fuels release different amounts of carbon dioxide for the same level of energy use:...
# ========
# Series: EN.ATM.CO2E.GF.KT
#
# Statisticalconceptandmethodology: ...from fossil fuel combustion and cement manufacturing. In combustion different fossil fuels release different amounts of carbon dioxide for the same level of energy use:...
# ========
# Series: EN.ATM.CO2E.GF.ZS
#
# Statisticalconceptandmethodology: ...from fossil fuel combustion and cement manufacturing. In combustion different fossil fuels release different amounts of carbon dioxide for the same level of energy use:...
# ========
# Series: EN.ATM.CO2E.KD.GD
#
# Longdefinition: ...Carbon dioxide emissions are those stemming from the burning of fossil fuels and the manufacture of cement. They include carbon dioxide produced during...
# ========
# Series: EN.ATM.CO2E.KT
#
# Longdefinition: ...Carbon dioxide emissions are those stemming from the burning of fossil fuels and the manufacture of cement. They include carbon dioxide produced during...
# --------
# Statisticalconceptandmethodology: ...from fossil fuel combustion and cement manufacturing. In combustion different fossil fuels release different amounts of carbon dioxide for the same level of energy use:...
# ========
# Series: EN.ATM.CO2E.LF.KT
#
# Statisticalconceptandmethodology: ...from fossil fuel combustion and cement manufacturing. In combustion different fossil fuels release different amounts of carbon dioxide for the same level of energy use:...
# ========
# Series: EN.ATM.CO2E.LF.ZS
#
# Statisticalconceptandmethodology: ...from fossil fuel combustion and cement manufacturing. In combustion different fossil fuels release different amounts of carbon dioxide for the same level of energy use:...
# ========
# Series: EN.ATM.CO2E.PC
#
# Longdefinition: ...Carbon dioxide emissions are those stemming from the burning of fossil fuels and the manufacture of cement. They include carbon dioxide produced during...
# --------
# Statisticalconceptandmethodology: ...from fossil fuel combustion and cement manufacturing. In combustion different fossil fuels release different amounts of carbon dioxide for the same level of energy use:...
# ========
# Series: EN.ATM.CO2E.PP.GD
#
# Longdefinition: ...Carbon dioxide emissions are those stemming from the burning of fossil fuels and the manufacture of cement. They include carbon dioxide produced during...
# ========
# Series: EN.ATM.CO2E.PP.GD.KD
#
# Limitationsandexceptions: ...Data for carbon dioxide emissions include gases from the burning of fossil fuels and cement manufacture, but excludes emissions from land use such as...
# --------
# Longdefinition: ...Carbon dioxide emissions are those stemming from the burning of fossil fuels and the manufacture of cement. They include carbon dioxide produced during...
# --------
# Statisticalconceptandmethodology: ...from fossil fuel combustion and cement manufacturing. In combustion different fossil fuels release different amounts of carbon dioxide for the same level of energy use:...
# ========
# Series: EN.ATM.CO2E.SF.KT
#
# Statisticalconceptandmethodology: ...from fossil fuel combustion and cement manufacturing. In combustion different fossil fuels release different amounts of carbon dioxide for the same level of energy use:...
# ========
# Series: EN.ATM.METH.EG.KT.CE
#
# Longdefinition: ...are emissions from the production, handling, transmission, and combustion of fossil fuels and biofuels....
# ========
# Series: EN.ATM.METH.EG.ZS
#
# Longdefinition: ...are emissions from the production, handling, transmission, and combustion of fossil fuels and biofuels....
# ========
# Series: EN.ATM.NOXE.EG.KT.CE
#
# Longdefinition: ...emissions from energy processes are emissions produced by the combustion of fossil fuels and biofuels....
# ========
# Series: EN.ATM.NOXE.EG.ZS
#
# Longdefinition: ...emissions from energy processes are emissions produced by the combustion of fossil fuels and biofuels....
# ========
# Series: EN.CO2.BLDG.MT
#
# Statisticalconceptandmethodology: ...from fossil fuel combustion and cement manufacturing. In combustion different fossil fuels release different amounts of carbon dioxide for the same level of energy use:...
# ========
# Series: EN.CO2.BLDG.ZS
#
# Statisticalconceptandmethodology: ...from fossil fuel combustion and cement manufacturing. In combustion different fossil fuels release different amounts of carbon dioxide for the same level of energy use:...
# ========
# Series: EN.CO2.ETOT.MT
#
# Statisticalconceptandmethodology: ...from fossil fuel combustion and cement manufacturing. In combustion different fossil fuels release different amounts of carbon dioxide for the same level of energy use:...
# ========
# Series: EN.CO2.ETOT.ZS
#
# Statisticalconceptandmethodology: ...from fossil fuel combustion and cement manufacturing. In combustion different fossil fuels release different amounts of carbon dioxide for the same level of energy use:...
# ========
# Series: EN.CO2.MANF.MT
#
# Statisticalconceptandmethodology: ...from fossil fuel combustion and cement manufacturing. In combustion different fossil fuels release different amounts of carbon dioxide for the same level of energy use:...
# ========
# Series: EN.CO2.MANF.ZS
#
# Statisticalconceptandmethodology: ...from fossil fuel combustion and cement manufacturing. In combustion different fossil fuels release different amounts of carbon dioxide for the same level of energy use:...
# ========
# Series: EN.CO2.OTHX.MT
#
# Statisticalconceptandmethodology: ...from fossil fuel combustion and cement manufacturing. In combustion different fossil fuels release different amounts of carbon dioxide for the same level of energy use:...
# ========
# Series: EN.CO2.OTHX.ZS
#
# Statisticalconceptandmethodology: ...from fossil fuel combustion and cement manufacturing. In combustion different fossil fuels release different amounts of carbon dioxide for the same level of energy use:...
# ========
# Series: EN.CO2.TRAN.MT
#
# Statisticalconceptandmethodology: ...from fossil fuel combustion and cement manufacturing. In combustion different fossil fuels release different amounts of carbon dioxide for the same level of energy use:...
# ========
# Series: EN.CO2.TRAN.ZS
#
# Statisticalconceptandmethodology: ...from fossil fuel combustion and cement manufacturing. In combustion different fossil fuels release different amounts of carbon dioxide for the same level of energy use:...
# ========
# Series: NY.GDP.COAL.RT.ZS
#
# Developmentrelevance: ...development. In some countries earnings from natural resources, especially from fossil fuels and minerals, account for a sizable share of GDP, and much of these earnings...
# ========
# Series: NY.GDP.FRST.RT.ZS
#
# Developmentrelevance: ...development. In some countries earnings from natural resources, especially from fossil fuels and minerals, account for a sizable share of GDP, and much of these earnings...
# ========
# Series: NY.GDP.MINR.RT.ZS
#
# Developmentrelevance: ...development. In some countries earnings from natural resources, especially from fossil fuels and minerals, account for a sizable share of GDP, and much of these earnings...
# ========
# Series: NY.GDP.NGAS.RT.ZS
#
# Developmentrelevance: ...development. In some countries earnings from natural resources, especially from fossil fuels and minerals, account for a sizable share of GDP, and much of these earnings...
# ========
# Series: NY.GDP.PETR.RT.ZS
#
# Developmentrelevance: ...development. In some countries earnings from natural resources, especially from fossil fuels and minerals, account for a sizable share of GDP, and much of these earnings...
# ========
# Series: NY.GDP.TOTL.RT.ZS
#
# Developmentrelevance: ...development. In some countries earnings from natural resources, especially from fossil fuels and minerals, account for a sizable share of GDP, and much of these earnings...
